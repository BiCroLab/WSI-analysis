# %%
import plotly.graph_objects as go
import networkx as nx
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import sparse
sns.set()

# %%
import glob, os
import matplotlib.pyplot as plt

pattern="*.txt.degree"

os.chdir("/media/garner1/hdd2/DAPI/old")
fig = plt.figure(figsize=(20,12))
for file in glob.glob(pattern):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,hist=False,label=file)
labels1=[file for file in glob.glob(pattern)]

os.chdir("/media/garner1/hdd2/ND2/segmentation")
for file in glob.glob(pattern):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,hist=False,label=file)
labels2=[file for file in glob.glob(pattern)]
# Out:
# 4__iMS341_20190710_001.tif.8bit.convert.imgcnv.tif.Detections.txt.degree
# 2__iMS337_20190709_001.tif.8bit.convert.imgcnv.tif.Detections.txt.degree
# 57__iMS313_20190627_001.tif.8bit.convert.imgcnv.tif.Detections.txt.degree
# 52.nd2.txt.degree

# %%
pattern="*.txt.degree"

os.chdir("/media/garner1/hdd2/HE/segmentation")
fig = plt.figure(figsize=(20,12))
for file in glob.glob(pattern):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,hist=False,label=file)
labels=[file for file in glob.glob(pattern)]
# Out:
# MN4__33230-2.svs.Detections.txt.degree
# MN2__10309-2.svs.Detections.txt.degree
# MN52__18732_15-52.svs.Detections.txt.degree
# MN57__949233-57.svs.Detections.txt.degree

# %%
pattern1="2__*.txt.degree"
pattern2="MN2__*.txt.degree"

os.chdir("/media/garner1/hdd2/DAPI/old")
fig = plt.figure(figsize=(15,9))
for file in glob.glob(pattern1):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
DAPIlabels=[file for file in glob.glob(pattern1)]

os.chdir("/media/garner1/hdd2/HE/segmentation")
for file in glob.glob(pattern2):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
HElabels=[file for file in glob.glob(pattern2)]
# Out:
# 2__iMS337_20190709_001.tif.8bit.convert.imgcnv.tif.Detections.txt.degree
# MN2__10309-2.svs.Detections.txt.degree

# %%
pattern1="4__*.txt.degree"
pattern2="MN4__*.txt.degree"

os.chdir("/media/garner1/hdd2/DAPI/old")
fig = plt.figure(figsize=(15,9))
for file in glob.glob(pattern1):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
DAPIlabels=[file for file in glob.glob(pattern1)]

os.chdir("/media/garner1/hdd2/HE/segmentation")
for file in glob.glob(pattern2):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
HElabels=[file for file in glob.glob(pattern2)]
# Out:
# 4__iMS341_20190710_001.tif.8bit.convert.imgcnv.tif.Detections.txt.degree
# MN4__33230-2.svs.Detections.txt.degree

# %%
pattern1="52*.txt.degree"
pattern2="MN52__*.txt.degree"

os.chdir("/media/garner1/hdd2/ND2/segmentation")
fig = plt.figure(figsize=(15,9))
for file in glob.glob(pattern1):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
DAPIlabels=[file for file in glob.glob(pattern1)]

os.chdir("/media/garner1/hdd2/HE/segmentation")
for file in glob.glob(pattern2):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
HElabels=[file for file in glob.glob(pattern2)]
# Out:
# 52.nd2.txt.degree
# MN52__18732_15-52.svs.Detections.txt.degree

# %%
pattern1="57__*.txt.degree"
pattern2="MN57__*.txt.degree"

os.chdir("/media/garner1/hdd2/DAPI/old")
fig = plt.figure(figsize=(15,9))
for file in glob.glob(pattern1):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
DAPIlabels=[file for file in glob.glob(pattern1)]

os.chdir("/media/garner1/hdd2/HE/segmentation")
for file in glob.glob(pattern2):
    print(file)
    cc = np.loadtxt(file)
    sns.distplot(cc,label=file,hist=False)
HElabels=[file for file in glob.glob(pattern2)]
# Out:
# 57__iMS313_20190627_001.tif.8bit.convert.imgcnv.tif.Detections.txt.degree
# MN57__949233-57.svs.Detections.txt.degree
